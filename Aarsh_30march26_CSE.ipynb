# %%
tup_1=("a","b","c")
l1=list(tup_1)
l1.append("d")
tup_1=tuple(l1)
print(tup_1)
# Out:
# ('a', 'b', 'c', 'd')

# %%
student=["Aryan","Atharva","Aarsh","Aryan"]
print(student)
unstudent=set(student)
print(unstudent)
student= list(unstudent)
print(student)
# Out:
# ['Aryan', 'Atharva', 'Aarsh', 'Aryan']
# {'Aryan', 'Aarsh', 'Atharva'}
# ['Aryan', 'Aarsh', 'Atharva']

# %%
stg="250"
b =int(stg)
print(type(b))

q2=99
q2a1=float(q2)
print(q2a1)
q2a2=str(q2)
print(q2a2)

x="45.67"
q3a1=float(x)
print(q3a1)
q3a2=int(q3a1)
print(q3a2)

q4=False
q4a1=int(q4)
print(q4a1)

q5=(10,20,30)
q5a1=list(q5)
print(q5a1)
# Out:
# <class 'int'>
# 99.0
# 99
# 45.67
# 45
# 0
# [10, 20, 30]

# %%
l1=[1,2,3,4,5]
print(l1[0])
print(l1[4])
print(len(l1))
# Out:
# 1
# 5
# 5

# %%
s="MachineLearning"
print(s[0:7])
print(s[10:15])
# Out:
# Machine
# rning

# %%
tup1=("a","b","c","d")
tup1[1] = "e"
#cant change the element in tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 tup1=("a","b","c","d")
# ----> 2 tup1[1] = "e"
#
# TypeError: 'tuple' object does not support item assignment

# %%
string1="python"
l1=list(string1)
print(l1)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
num=[5,10,15,20]
num.append(25)
num.remove(10)
print(num)
# Out:
# [5, 15, 20, 25]

# %%
string2="6789"
l1=list(string2)
print(l1)
# Out:
# ['6', '7', '8', '9']
