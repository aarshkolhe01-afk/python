# %%
print(15%2) #in modulo it shows remainder
print(15//2) #in floor division it round ups the value 
print(15**2) #it is used to give poewer
# Out:
# 1
# 7
# 225

# %%
x=5
x+=5
print(x)
x-=3
print(x)
x/=4
print(x)
x*=6
print(x)
# Out:
# 10
# 7
# 1.75
# 10.5

# %%
a=10
b=23
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a="hello"
b="bye"
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %%
A=65
a=97
print("A">"a")
# Out:
# False

# %%
a=12
b=23
print(a>0 and b>36)
print(a>0 or b>36)
print(a!=2 or b!=28)
# Out:
# False
# True
# True

# %%
x=[2,3,4]
y=[2,3,4]
z=x
print(x is y)
print(y is z)
# Out:
# False
# False

# %%
x=10
if(x>100):
    if(x%2==0):
        print("even")        
else:
    print("value is greater than 100")
