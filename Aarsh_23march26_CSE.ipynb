# %%
a=10
b=1.2
c="Python"
d= True

print("the variable a=",(a),type(a))
print("the variable b=",(b),type(b))
print("the variable c=",(c),type(c))
print("the variable d=",(d),type(d))
# Out:
# the variable a= 10 <class 'int'>
# the variable b= 1.2 <class 'float'>
# the variable c= Python <class 'str'>
# the variable d= True <class 'bool'>

# %%
fruit=["apple","banana","kiwi","coconut","walnut","guava","peach"]
fruit.append("graps")
fruit.append("strawberry")
fruit.append("orange")
print(fruit)
fruit.remove("apple")
print(fruit)
fruit.extend({"dragonfruit"})
print(fruit)
# Out:
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'guava', 'peach', 'graps', 'strawberry', 'orange']
# ['banana', 'kiwi', 'coconut', 'walnut', 'guava', 'peach', 'graps', 'strawberry', 'orange']
# ['banana', 'kiwi', 'coconut', 'walnut', 'guava', 'peach', 'graps', 'strawberry', 'orange', 'dragonfruit']
