# %%
a=int(input(print("Enter 1st no")))
b=int(input(print("Enter 2st no")))
print("the sum is ",a+b)
print("the diff is ",a-b)
print("the mul is ",a*b)
print("the div is ",a/b)
print("the remainder is ",a%b)
print("the integer div is ",int(a/b))
# Out:
# Enter 1st no
# Enter 2st no
# the sum is  101
# the diff is  -11
# the mul is  2520
# the div is  0.8035714285714286
# the remainder is  45
# the integer div is  0

# %%
age=int(input(print("age")))
if (age>18):
    print("eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# age
# Not eligible to vote

# %%
for i in range(5):
    print("python")
# Out:
# python
# python
# python
# python
# python

# %%
i=1
while (i<11):
    if(i%2==0):
        print(i) 
    i+=1
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
sec=int(input(print("enter total no of sec")))
mins=int(sec/60)
rs=sec%60
print(mins,sec)
# Out:
# enter total no of sec
# 10 611
